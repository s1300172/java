# %%
:Description:
    Lambda function that increments a number by one.

**Terminal command**

Format:

    python3 plusOne.py

Example Usage:

    python3 plusOne.py
"""

plusOne = lambda x: x + 1

print("plusOne(2) =", plusOne(2))
